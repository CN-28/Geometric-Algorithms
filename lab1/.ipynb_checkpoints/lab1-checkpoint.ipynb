# %% [markdown]
# # Laboratorium

# %% [markdown]
# ### Konfiguracja

# %%
# Narzędzie jest oparte o kilka zewnętrznych bibliotek, które potrzebujemy najpierw zaimportować.
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.collections as mcoll
import matplotlib.colors as mcolors
from matplotlib.widgets import Button
import json as js
import pandas as pd

# Parametr określający jak blisko (w odsetku całego widocznego zakresu) punktu początkowego 
# wielokąta musimy kliknąć, aby go zamknąć.
TOLERANCE = 0.15

def dist(point1, point2):
    return np.sqrt(np.power(point1[0] - point2[0], 2) + np.power(point1[1] - point2[1], 2))

# Klasa ta trzyma obecny stan wykresu oraz posiada metody, które mają zostać wykonane
# po naciśnięciu przycisków.
class _Button_callback(object):
    def __init__(self, scenes):
        self.i = 0
        self.scenes = scenes
        self.adding_points = False
        self.added_points = []
        self.adding_lines = False
        self.added_lines = []
        self.adding_rects = False
        self.added_rects = []

    def set_axes(self, ax):
        self.ax = ax
        
    # Metoda ta obsługuje logikę przejścia do następnej sceny.
    def next(self, event):
        self.i = (self.i + 1) % len(self.scenes)
        self.draw(autoscaling = True)

    # Metoda ta obsługuje logikę powrotu do poprzedniej sceny.
    def prev(self, event):
        self.i = (self.i - 1) % len(self.scenes)
        self.draw(autoscaling = True)
        
    # Metoda ta aktywuje funkcję rysowania punktów wyłączając równocześnie rysowanie 
    # odcinków i wielokątów.
    def add_point(self, event):
        self.adding_points = not self.adding_points
        self.new_line_point = None
        if self.adding_points:
            self.adding_lines = False
            self.adding_rects = False
            self.added_points.append(PointsCollection([]))
            
    # Metoda ta aktywuje funkcję rysowania odcinków wyłączając równocześnie
    # rysowanie punktów i wielokątów.     
    def add_line(self, event):   
        self.adding_lines = not self.adding_lines
        self.new_line_point = None
        if self.adding_lines:
            self.adding_points = False
            self.adding_rects = False
            self.added_lines.append(LinesCollection([]))

    # Metoda ta aktywuje funkcję rysowania wielokątów wyłączając równocześnie
    # rysowanie punktów i odcinków.
    def add_rect(self, event):
        self.adding_rects = not self.adding_rects
        self.new_line_point = None
        if self.adding_rects:
            self.adding_points = False
            self.adding_lines = False
            self.new_rect()
    
    def new_rect(self):
        self.added_rects.append(LinesCollection([]))
        self.rect_points = []
        
    # Metoda odpowiedzialna za właściwą logikę rysowania nowych elementów. W
    # zależności od włączonego trybu dodaje nowe punkty, początek, koniec odcinka
    # lub poszczególne wierzchołki wielokąta. Istnieje ciekawa logika sprawdzania
    # czy dany punkt jest domykający dla danego wielokąta. Polega ona na tym, że
    # sprawdzamy czy odległość nowego punktu od początkowego jest większa od
    # średniej długości zakresu pomnożonej razy parametr TOLERANCE.   
    def on_click(self, event):
        if event.inaxes != self.ax:
            return
        new_point = (event.xdata, event.ydata)
        if self.adding_points:
            self.added_points[-1].add_points([new_point])
            self.draw(autoscaling = False)
        elif self.adding_lines:
            if self.new_line_point is not None:
                self.added_lines[-1].add([self.new_line_point, new_point])
                self.new_line_point = None
                self.draw(autoscaling = False)
            else:
                self.new_line_point = new_point
        elif self.adding_rects:
            if len(self.rect_points) == 0:
                self.rect_points.append(new_point)
            elif len(self.rect_points) == 1:
                self.added_rects[-1].add([self.rect_points[-1], new_point])
                self.rect_points.append(new_point)
                self.draw(autoscaling = False)
            elif len(self.rect_points) > 1:
                if dist(self.rect_points[0], new_point) < (np.mean([self.ax.get_xlim(), self.ax.get_ylim()])*TOLERANCE):
                    self.added_rects[-1].add([self.rect_points[-1], self.rect_points[0]])
                    self.new_rect()
                else:    
                    self.added_rects[-1].add([self.rect_points[-1], new_point])
                    self.rect_points.append(new_point)
                self.draw(autoscaling = False)
    
    # Metoda odpowiedzialna za narysowanie całego wykresu. Warto zauważyć,
    # że zaczyna się ona od wyczyszczenia jego wcześniejszego stanu. Istnieje w
    # niej nietrywialna logika zarządzania zakresem wykresu, tak żeby, w zależności
    # od ustawionego parametru autoscaling, uniknąć sytuacji, kiedy dodawanie
    # nowych punktów przy brzegu obecnie widzianego zakresu powoduje niekorzystne
    # przeskalowanie.
    def draw(self, autoscaling = True):
        if not autoscaling:
            xlim = self.ax.get_xlim()
            ylim = self.ax.get_ylim()
        self.ax.clear()
        for collection in (self.scenes[self.i].points + self.added_points):
            if len(collection.points) > 0:
                self.ax.scatter(*zip(*(np.array(collection.points))), **collection.kwargs)
        for collection in (self.scenes[self.i].lines + self.added_lines + self.added_rects):
            self.ax.add_collection(collection.get_collection())
        self.ax.autoscale(autoscaling)
        if not autoscaling:
            self.ax.set_xlim(xlim)
            self.ax.set_ylim(ylim)
        plt.draw()

# %% [markdown]
# ### Interfejsy
#
# [Dostępne kolory](https://matplotlib.org/3.1.1/gallery/color/named_colors.html)
#
# [Dostępne znaczniki punktów](https://matplotlib.org/3.1.1/api/markers_api.html#module-matplotlib.markers)

# %%
# Klasa Scene odpowiada za przechowywanie elementów, które mają być
# wyświetlane równocześnie. Konkretnie jest to lista PointsCollection i
# LinesCollection.
class Scene:
    def __init__(self, points=[], lines=[]):
        self.points=points
        self.lines=lines

# Klasa PointsCollection gromadzi w sobie punkty jednego typu, a więc takie,
# które zostaną narysowane w takim samym kolorze i stylu. W konstruktorze
# przyjmuje listę punktów rozumianych jako pary współrzędnych (x, y). Parametr
# kwargs jest przekazywany do wywołania funkcji z biblioteki MatPlotLib przez
# co użytkownik może podawać wszystkie parametry tam zaproponowane.        
class PointsCollection:
    def __init__(self, points, **kwargs):
        self.points = points
        self.kwargs = kwargs
    
    def add_points(self, points):
        self.points = self.points + points

# Klasa LinesCollection podobnie jak jej punktowy odpowiednik gromadzi
# odcinki tego samego typu. Tworząc ją należy podać listę linii, gdzie każda
# z nich jest dwuelementową listą punktów – par (x, y). Parametr kwargs jest
# przekazywany do wywołania funkcji z biblioteki MatPlotLib przez co użytkownik
# może podawać wszystkie parametry tam zaproponowane.
class LinesCollection:
    def __init__(self, lines, **kwargs):
        self.lines = lines
        self.kwargs = kwargs
        
    def add(self, line):
        self.lines.append(line)
        
    def get_collection(self):
        return mcoll.LineCollection(self.lines, **self.kwargs)

# Klasa Plot jest najważniejszą klasą w całym programie, ponieważ agreguje
# wszystkie przygotowane sceny, odpowiada za stworzenie wykresu i przechowuje
# referencje na przyciski, dzięki czemu nie będą one skasowane podczas tzw.
# garbage collectingu.
class Plot:
    def __init__(self, scenes = [Scene()], points = [], lines = [], json = None):
        if json is None:
            self.scenes = scenes
            if points or lines:
                self.scenes[0].points = points
                self.scenes[0].lines = lines
        else:
            self.scenes = [Scene([PointsCollection(pointsCol) for pointsCol in scene["points"]], 
                                 [LinesCollection(linesCol) for linesCol in scene["lines"]]) 
                           for scene in js.loads(json)]
    
    # Ta metoda ma szczególne znaczenie, ponieważ konfiguruje przyciski i
    # wykonuje tym samym dość skomplikowaną logikę. Zauważmy, że konfigurując każdy
    # przycisk podajemy referencję na metodę obiektu _Button_callback, która
    # zostanie wykonana w momencie naciśnięcia.
    def __configure_buttons(self):
        plt.subplots_adjust(bottom=0.2)
        ax_prev = plt.axes([0.6, 0.05, 0.15, 0.075])
        ax_next = plt.axes([0.76, 0.05, 0.15, 0.075])
        ax_add_point = plt.axes([0.44, 0.05, 0.15, 0.075])
        ax_add_line = plt.axes([0.28, 0.05, 0.15, 0.075])
        ax_add_rect = plt.axes([0.12, 0.05, 0.15, 0.075])
        b_next = Button(ax_next, 'Następny')
        b_next.on_clicked(self.callback.next)
        b_prev = Button(ax_prev, 'Poprzedni')
        b_prev.on_clicked(self.callback.prev)
        b_add_point = Button(ax_add_point, 'Dodaj punkt')
        b_add_point.on_clicked(self.callback.add_point)
        b_add_line = Button(ax_add_line, 'Dodaj linię')
        b_add_line.on_clicked(self.callback.add_line)
        b_add_rect = Button(ax_add_rect, 'Dodaj figurę')
        b_add_rect.on_clicked(self.callback.add_rect)
        return [b_prev, b_next, b_add_point, b_add_line, b_add_rect]
    
    def add_scene(self, scene):
        self.scenes.append(scene)
    
    def add_scenes(self, scenes):
        self.scenes = self.scenes + scenes

    # Metoda toJson() odpowiada za zapisanie stanu obiektu do ciągu znaków w
    # formacie JSON.
    def toJson(self):
        return js.dumps([{"points": [np.array(pointCol.points).tolist() for pointCol in scene.points], 
                          "lines":[linesCol.lines for linesCol in scene.lines]} 
                         for scene in self.scenes])    
    
    # Metoda ta zwraca punkty dodane w trakcie rysowania.
    def get_added_points(self):
        if self.callback:
            return self.callback.added_points
        else:
            return None
    
    # Metoda ta zwraca odcinki dodane w trakcie rysowania.
    def get_added_lines(self):
        if self.callback:
            return self.callback.added_lines
        else:
            return None
        
    # Metoda ta zwraca wielokąty dodane w trakcie rysowania.
    def get_added_figure(self):
        if self.callback:
            return self.callback.added_rects
        else:
            return None
    
    # Metoda ta zwraca punkty, odcinki i wielokąty dodane w trakcie rysowania
    # jako scenę.
    def get_added_elements(self):
        if self.callback:
            return Scene(self.callback.added_points, self.callback.added_lines+self.callback.added_rects)
        else:
            return None
    
    # Główna metoda inicjalizująca wyświetlanie wykresu.
    def draw(self):
        plt.close()
        fig = plt.figure()
        self.callback = _Button_callback(self.scenes)
        self.widgets = self.__configure_buttons()
        ax = plt.axes(autoscale_on = False)
        self.callback.set_axes(ax)
        fig.canvas.mpl_connect('button_press_event', self.callback.on_click)
        plt.show()
        self.callback.draw()

# %% [markdown]
# ### Przykłady użycia

# %% [markdown]
# ##### Proste rysowanie
#
# Rysowanie prostego rysunku złożonego ze statycznych punktów i odcinków jest stosunkowo proste. Należy utworzyć zmienną z obiektem `Plot`, który przyjmuje w konstruktorze listę obiektów `PointsCollection` jako parametr `points` oraz listę `LinesCollection` jako parametr `lines`. Następnie należy wywołać jego metodę `draw()`.

# %%
# %matplotlib notebook

plot = Plot(points=[PointsCollection([(1, 2), (3, 1.5), (2, -1)]),
               PointsCollection([(5, -2), (2, 2), (-2, -1)], color='green', marker = "^")],
            lines=[LinesCollection([[(1,2),(2,3)], [(0,1),(1,0)]])])
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ##### Rysunek dynamiczny
#
# To narzędzie pozwala na wizualizację "rysunków dynamicznych", a więc takich, które składają się z wielu różnych obrazów. Może to być przydatne np. podczas wizualizacji kolejnych kroków danego algorytmu. Poszczególne klatki określane są jako obiekty `Scene`, które przyjmują listę `PointsCollection` oraz listę `LinesCollection` w swoim konstruktorze. Obiekt `Plot` przyjmuje w parametrze konstruktora `scenes` właśnie listę takich scen.
#
# Na rysunku przyciski `Następny` i `Poprzedni` służą do nawigacji pomiędzy nimi.

# %%
# %matplotlib notebook

scenes=[Scene([PointsCollection([(1, 2), (3, 1.5), (2, -1)]), 
               PointsCollection([(5, -2), (2, 2), (-2, -1)], color='green', marker = "^")], 
              [LinesCollection([[(1,2),(2,3)], [(0,1),(1,0)]])]), 
        Scene([PointsCollection([(1, 2), (3, 1.5), (2, -1)], color='red'), 
               PointsCollection([(5, -2), (2, 2), (-2, 1)], color='black')], 
              [LinesCollection([[(-1,2),(-2,3)], [(0,-1),(-1,0)]])])]

plot=Plot(scenes = scenes)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ###### Zapis i odczyt z pliku
#
# Klasa Plot posiada metodę `toJson()`, która zwraca string zawierający listę scen w formacie JSON. Taki string można normalnie zapisać do pliku stosując normalne sposoby dostępne w Pythonie. Wczytanie listy scen z pliku dokonuje się poprzez podanie parametru `json` w kostruktorze `Plot`.

# %%
scenes=[Scene([PointsCollection([(-2, -1)], color='green', marker = "^")], 
              [LinesCollection([[(1,2),(2,3)], [(0,1),(1,0)]])]), 
        Scene([PointsCollection([(1, 2), (3, 1.5)], color='red'), 
               PointsCollection([(5, -2)], color='black')])]
plot = Plot(scenes)

with open('somefile.json', 'w') as file:
    file.write(plot.toJson())
    
#somefile.json: [{"points": [[[-2, -1]]], "lines": [[[[1, 2], [2, 3]], [[0, 1], [1, 0]]]]}, {"points": [[[1.0, 2.0], [3.0, 1.5]], [[5, -2]]], "lines": []}]
    
with open('somefile.json', 'r') as file:
    json = file.read()
    
plot2 = Plot(json=json)
plot2.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ##### Operowanie na dodanych punktach
#
# Możemy bardzo łatwo rysować nowe punkty i linie. Aby je później wykorzystać sugerowanym sposobem jest utworzenie nowej komórki, w której utworzymy nowy `Plot` i skorzystamy z metod `get_added_points()` i `get_added_points()` lub `get_added_elements()` (zwraca scenę) z pierwszego `Plot`u.

# %%
#Dodaj tu punkty, figury i/lub odcinki!
plot1 = Plot()
plot1.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot2 = Plot([plot1.get_added_elements()])
plot2.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Rozwiązanie

# %%
import random
import math
# %matplotlib notebook

# %% [markdown]
# ## a) 10<sup>5</sup> losowych punktów o współrzędnych z przedziału [-1000, 1000]

# %%
A = [(random.uniform(-1000, 1000), random.uniform(-1000, 1000)) for _ in range(10**5)]
plot = Plot(points = [PointsCollection(A)])
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## b) 10<sup>5</sup> losowych punktów o współrzędnych z przedziału [-10<sup>14</sup>, 10<sup>14</sup>]

# %%
B = [(random.uniform(-10**14, 10**14), random.uniform(-10**14, 10**14)) for _ in range(10**5)]
plot = Plot(points = [PointsCollection(B)])
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## c) 1000 losowych punktów leżących na okręgu o środku (0,0) i promieniu R=100

# %%
C = []
R = 100
for _ in range(1000):
    fi = random.uniform(0, 2 * math.pi)
    C.append((R * math.cos(fi), R * math.sin(fi)))

plot = Plot(points = [PointsCollection(C)])
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## d) 1000 losowych punktów o współrzędnych z przedziału [-1000, 1000] leżących na prostej wyznaczonej przez wektor (a, b), a = [-1.0, 0.0], b = [1.0, 0.1]

# %%
#wyznaczanie punktów z postaci parametrycznej prostej
D = []
a, b = (-1.0, 0.0), (1.0, 0.1)
AB = (b[0] - a[0], b[1] - a[1])
for _ in range(1000):
    x = random.uniform(-1000, 1000)
    t = (x - a[0]) / AB[0]
    y = a[1] + t * AB[1]
    D.append((x, y))

plot = Plot(points = [PointsCollection(D)])
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Funkcje obliczające wyznacznik 2x2

# %%
def det2x2(a, b, c):
    return (a[0] - c[0]) * (b[1] - c[1]) - (a[1] - c[1]) * (b[0] - c[0])

def det2x2_np(a, b, c):
    return np.linalg.det(np.array(((a[0] - c[0], a[1] - c[1]), (b[0] - c[0], b[1] - c[1]))))

# %% [markdown]
# ## Funkcje obliczające wyznacznik 3x3

# %%
def det3x3(a, b, c):
    return a[0] * b[1] + b[0] * c[1] + c[0] * a[1] - b[1] * c[0] - b[0] * a[1] - a[0] * c[1]

def det3x3_np(a, b, c):
    return np.linalg.det(np.array(((a[0], a[1], 1), (b[0], b[1], 1), (c[0], c[1], 1))))

# %% [markdown]
# ## Konfiguracja tolerancji

# %%
tolerances = [10**-18, 10**-13, 10**-8]
default = tolerances[0]
epsilon = {"a": default, "b": default, "c": default, "d": default}

# %% [markdown]
# ## Funkcja klasyfikująca punkty

# %%
def classify(points, det, epsilon, a, b):
    classified = {
        "left": [],
        "collinear": [],
        "right": []
    }
    
    for point in points:
        res = det(a, b, point)
        if res > epsilon:
            classified["right"].append(point)
        elif res < -epsilon:
            classified["left"].append(point)
        else:
            classified["collinear"].append(point)
    
    return classified

# %% [markdown]
# ## Funkcja wyświetlająca zaklasyfikowane punkty

# %%
def printClassified(classified):
    plot = Plot(points = [PointsCollection(classified["left"], color = "green"), PointsCollection(classified["right"], color = "red"), PointsCollection(classified["collinear"], color = "yellow")])
    plot.draw()
    print("Left: ", len(classified["left"]))
    print("Collinear: ", len(classified["collinear"]))
    print("Right: ", len(classified["right"]))

# %% [markdown]
# # Porównania dla podpunktu a)

# %% [markdown]
# ## 1. Własny wyznacznik 2x2

# %%
printClassified(classify(A, det2x2, epsilon['a'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  49895
# Collinear:  0
# Right:  50105

# %% [markdown]
# ## 2. Wyznacznik 2x2 z biblioteki numpy

# %%
printClassified(classify(A, det2x2_np, epsilon['a'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  49895
# Collinear:  0
# Right:  50105

# %% [markdown]
# ## 3. Własny wyznacznik 3x3

# %%
printClassified(classify(A, det3x3, epsilon['a'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  49895
# Collinear:  0
# Right:  50105

# %% [markdown]
# ## 4. Wyznacznik 3x3 z biblioteki numpy

# %%
printClassified(classify(A, det3x3_np, epsilon['a'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  49895
# Collinear:  0
# Right:  50105

# %% [markdown]
# # Porównania dla podpunktu b)

# %% [markdown]
# ## 1. Własny wyznacznik 2x2

# %%
printClassified(classify(B, det2x2, epsilon['b'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  50058
# Collinear:  8
# Right:  49934

# %% [markdown]
# ## 2. Wyznacznik 2x2 z biblioteki numpy

# %%
printClassified(classify(B, det2x2_np, epsilon['b'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  50057
# Collinear:  9
# Right:  49934

# %% [markdown]
# ## 3. Wyznacznik własny 3x3

# %%
printClassified(classify(B, det3x3, epsilon['b'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  50060
# Collinear:  0
# Right:  49940

# %% [markdown]
# ## 4. Wyznacznik 3x3 z biblioteki numpy

# %%
printClassified(classify(B, det3x3_np, epsilon['b'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  50060
# Collinear:  0
# Right:  49940

# %% [markdown]
# # Porównania dla podpunktu c)

# %% [markdown]
# ### 1. Wyznacznik własny 2x2

# %%
printClassified(classify(C, det2x2, epsilon['c'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  507
# Collinear:  0
# Right:  493

# %% [markdown]
# ### 2. Wyznacznik 2x2 z biblioteki numpy

# %%
printClassified(classify(C, det2x2_np, epsilon['c'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  507
# Collinear:  0
# Right:  493

# %% [markdown]
# ### 3. Wyznacznik własny 3x3

# %%
printClassified(classify(C, det3x3, epsilon['c'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  507
# Collinear:  0
# Right:  493

# %% [markdown]
# ### 4. Wyznacznik 3x3 z biblioteki numpy

# %%
printClassified(classify(C, det3x3_np, epsilon['c'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  507
# Collinear:  0
# Right:  493

# %% [markdown]
# # Porównania dla podpunktu d)

# %% [markdown]
# ### 1. Wyznacznik własny 2x2

# %%
printClassified(classify(D, det2x2, epsilon['d'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  150
# Collinear:  699
# Right:  151

# %% [markdown]
# ### 2. Wyznacznik 2x2 z biblioteki numpy

# %%
printClassified(classify(D, det2x2_np, epsilon['d'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  152
# Collinear:  702
# Right:  146

# %% [markdown]
# ### 3. Wyznacznik własny 3x3

# %%
printClassified(classify(D, det3x3, epsilon['d'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  385
# Collinear:  356
# Right:  259

# %% [markdown]
# ### 4. Wyznacznik 3x3 z biblioteki numpy

# %%
printClassified(classify(D, det3x3_np, epsilon['d'], a, b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Left:  399
# Collinear:  238
# Right:  363

# %% [markdown]
# ## Funkcja wyświetlająca różnice w klasyfikacji punktów

# %%
def drawDifferences(points, det1, det2, epsilon, a, b):
    getClassified1 = classify(points, det1, epsilon, a, b)
    res1 = []
    for key in getClassified1:
        for point in getClassified1[key]:
            res1.append((point, key))
        
    getClassified2 = classify(points, det2, epsilon, a, b)
    res2 = []
    for key in getClassified2:
        for point in getClassified2[key]:
            res2.append((point, key))
    
    res1.sort()
    res2.sort()
    diffsArr = []
    for i in range(len(res1)):
        if res1[i][1] != res2[i][1]:
            diffsArr.append(res1[i][0])
    
    if len(diffsArr) != 0:
        plot = Plot(points = [PointsCollection(diffsArr)])
        plot.draw()
    print(f"Differences: {len(diffsArr)}")

# %% [markdown]
# # Różnice między wyznacznikami dla wszystkich podpunktów

# %% [markdown]
# Wykresy obrazują punkty, które różnią się klasyfikacją dla porównywanych wyznaczników. Wykresy pojawiają się tylko wtedy, gdy liczba różnic jest większa od zera.

# %% [markdown]
# ### 1. Porównanie własnego wyznacznika 2x2 i 2x2 z biblioteki numpy

# %%
drawDifferences(A, det2x2, det2x2_np, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(B, det2x2, det2x2_np, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 7

# %%
drawDifferences(C, det2x2, det2x2_np, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(D, det2x2, det2x2_np, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 382

# %% [markdown]
# ### 2. Porównanie własnego wyznacznika 3x3 i 3x3 z biblioteki numpy

# %%
drawDifferences(A, det3x3, det3x3_np, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(B, det3x3, det3x3_np, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(C, det3x3, det3x3_np, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(D, det3x3, det3x3_np, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 539

# %% [markdown]
# ### 3. Porównanie własnego wyznacznika 2x2 i 3x3 z biblioteki numpy

# %%
drawDifferences(A, det2x2, det3x3_np, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(B, det2x2, det3x3_np, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 8

# %%
drawDifferences(C, det2x2, det3x3_np, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(D, det2x2, det3x3_np, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 696

# %% [markdown]
# ### 4. Porównanie własnego wyznacznika 2x2 i własnego wyznacznika 3x3

# %%
drawDifferences(A, det2x2, det3x3, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(B, det2x2, det3x3, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 8

# %%
drawDifferences(C, det2x2, det3x3, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(D, det2x2, det3x3, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 706

# %% [markdown]
# ### 5. Porównanie 3x3 z biblioteki numpy i 2x2 z biblioteki numpy

# %%
drawDifferences(A, det2x2_np, det3x3_np, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(B, det2x2_np, det3x3_np, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 10

# %%
drawDifferences(C, det2x2_np, det3x3_np, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(D, det2x2_np, det3x3_np, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 712

# %% [markdown]
# ### 6. Porównanie wyznacznika 2x2 z biblioteki numpy i własnego wyznacznika 3x3

# %%
drawDifferences(A, det2x2_np, det3x3, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(B, det2x2_np, det3x3, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 10

# %%
drawDifferences(C, det2x2_np, det3x3, default, a, b)
# Out:
# Differences: 0

# %%
drawDifferences(D, det2x2_np, det3x3, default, a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Differences: 696

# %% [markdown]
# ## Funkcja wyświetlająca różnice w klasyfikacji dla kombinacji wyznaczników i toleracji

# %%
def compare(points):
    scenes = []
    determinants = [(det2x2, "własny 2x2"), (det2x2_np, "2x2 numpy"), (det3x3, "własny 3x3"), (det3x3_np, "3x3 numpy")]
    for det, txt in determinants:
        print(f"[Wyznacznik {txt}]")
        for epsilon in tolerances:
            classified = classify(points, det, epsilon, a, b)
            left_len, collinear_len, right_len = len(classified["left"]), len(classified["collinear"]), len(classified["right"])
            print(f"[Tolerancja: {epsilon}], Left: {left_len}, Collinear: {collinear_len}, Right: {right_len}")
            scenes.append(Scene([PointsCollection(classified["left"], color = "red"), PointsCollection(classified["right"], color = "green"), PointsCollection(classified['collinear'], color='yellow')]))

    return scenes

# %% [markdown]
# # Porównanie kombinacji wyznaczników i tolerancji

# %% [markdown]
# Dla każdego podpunktu są slajdy z klasyfikacją punktów w kolejności takiej jak w tabelce nad danym wykresem. Aby przejrzeć slajdy należy uruchomić wcześniej komórkę danego podpunktu.

# %% [markdown]
# ### Podpunkt a)

# %%
plot = Plot(scenes = compare(A))
plot.draw()
# Out:
# [Wyznacznik własny 2x2]
# [Tolerancja: 1e-18], Left: 49895, Collinear: 0, Right: 50105
# [Tolerancja: 1e-13], Left: 49895, Collinear: 0, Right: 50105
# [Tolerancja: 1e-08], Left: 49895, Collinear: 0, Right: 50105
# [Wyznacznik 2x2 numpy]
# [Tolerancja: 1e-18], Left: 49895, Collinear: 0, Right: 50105
# [Tolerancja: 1e-13], Left: 49895, Collinear: 0, Right: 50105
# [Tolerancja: 1e-08], Left: 49895, Collinear: 0, Right: 50105
# [Wyznacznik własny 3x3]
# [Tolerancja: 1e-18], Left: 49895, Collinear: 0, Right: 50105
# [Tolerancja: 1e-13], Left: 49895, Collinear: 0, Right: 50105
# [Tolerancja: 1e-08], Left: 49895, Collinear: 0, Right: 50105
# [Wyznacznik 3x3 numpy]
# [Tolerancja: 1e-18], Left: 49895, Collinear: 0, Right: 50105
# [Tolerancja: 1e-13], Left: 49895, Collinear: 0, Right: 50105
# [Tolerancja: 1e-08], Left: 49895, Collinear: 0, Right: 50105
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Podpunkt b)

# %%
plot = Plot(scenes = compare(B))
plot.draw()
# Out:
# [Wyznacznik własny 2x2]
# [Tolerancja: 1e-18], Left: 50058, Collinear: 8, Right: 49934
# [Tolerancja: 1e-13], Left: 50058, Collinear: 8, Right: 49934
# [Tolerancja: 1e-08], Left: 50058, Collinear: 8, Right: 49934
# [Wyznacznik 2x2 numpy]
# [Tolerancja: 1e-18], Left: 50057, Collinear: 9, Right: 49934
# [Tolerancja: 1e-13], Left: 50057, Collinear: 9, Right: 49934
# [Tolerancja: 1e-08], Left: 50057, Collinear: 9, Right: 49934
# [Wyznacznik własny 3x3]
# [Tolerancja: 1e-18], Left: 50060, Collinear: 0, Right: 49940
# [Tolerancja: 1e-13], Left: 50060, Collinear: 0, Right: 49940
# [Tolerancja: 1e-08], Left: 50060, Collinear: 0, Right: 49940
# [Wyznacznik 3x3 numpy]
# [Tolerancja: 1e-18], Left: 50060, Collinear: 0, Right: 49940
# [Tolerancja: 1e-13], Left: 50060, Collinear: 0, Right: 49940
# [Tolerancja: 1e-08], Left: 50060, Collinear: 0, Right: 49940
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Podpunkt c)

# %%
plot = Plot(scenes = compare(C))
plot.draw()
# Out:
# [Wyznacznik własny 2x2]
# [Tolerancja: 1e-18], Left: 507, Collinear: 0, Right: 493
# [Tolerancja: 1e-13], Left: 507, Collinear: 0, Right: 493
# [Tolerancja: 1e-08], Left: 507, Collinear: 0, Right: 493
# [Wyznacznik 2x2 numpy]
# [Tolerancja: 1e-18], Left: 507, Collinear: 0, Right: 493
# [Tolerancja: 1e-13], Left: 507, Collinear: 0, Right: 493
# [Tolerancja: 1e-08], Left: 507, Collinear: 0, Right: 493
# [Wyznacznik własny 3x3]
# [Tolerancja: 1e-18], Left: 507, Collinear: 0, Right: 493
# [Tolerancja: 1e-13], Left: 507, Collinear: 0, Right: 493
# [Tolerancja: 1e-08], Left: 507, Collinear: 0, Right: 493
# [Wyznacznik 3x3 numpy]
# [Tolerancja: 1e-18], Left: 507, Collinear: 0, Right: 493
# [Tolerancja: 1e-13], Left: 507, Collinear: 0, Right: 493
# [Tolerancja: 1e-08], Left: 507, Collinear: 0, Right: 493
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Podpunkt d)

# %%
plot = Plot(scenes = compare(D))
plot.draw()
# Out:
# [Wyznacznik własny 2x2]
# [Tolerancja: 1e-18], Left: 150, Collinear: 699, Right: 151
# [Tolerancja: 1e-13], Left: 135, Collinear: 730, Right: 135
# [Tolerancja: 1e-08], Left: 0, Collinear: 1000, Right: 0
# [Wyznacznik 2x2 numpy]
# [Tolerancja: 1e-18], Left: 152, Collinear: 702, Right: 146
# [Tolerancja: 1e-13], Left: 138, Collinear: 732, Right: 130
# [Tolerancja: 1e-08], Left: 0, Collinear: 1000, Right: 0
# [Wyznacznik własny 3x3]
# [Tolerancja: 1e-18], Left: 385, Collinear: 356, Right: 259
# [Tolerancja: 1e-13], Left: 0, Collinear: 1000, Right: 0
# [Tolerancja: 1e-08], Left: 0, Collinear: 1000, Right: 0
# [Wyznacznik 3x3 numpy]
# [Tolerancja: 1e-18], Left: 399, Collinear: 238, Right: 363
# [Tolerancja: 1e-13], Left: 0, Collinear: 1000, Right: 0
# [Tolerancja: 1e-08], Left: 0, Collinear: 1000, Right: 0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Porównanie czasów wykonania dla poszczególnych wyznaczników

# %%
import time
start = time.time()
classify(A, det2x2, default, a, b)
print("[Własny wyznacznik 2x2]:", time.time() - start)

start = time.time()
classify(A, det2x2_np, default, a, b)
print("[Wyznacznik 2x2 numpy]:", time.time() - start)

start = time.time()
classify(A, det3x3, default, a, b)
print("[Własny wyznacznik 3x3]:", time.time() - start)

start = time.time()
classify(A, det3x3_np, default, a, b)
print("[Wyznacznik 3x3 numpy]:", time.time() - start)
# Out:
# [Własny wyznacznik 2x2]: 0.0770113468170166
# [Wyznacznik 2x2 numpy]: 1.009216070175171
# [Własny wyznacznik 3x3]: 0.1060023307800293
# [Wyznacznik 3x3 numpy]: 1.149031639099121
